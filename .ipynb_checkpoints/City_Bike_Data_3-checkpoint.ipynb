# %%
from zipfile import ZipFile
from urllib.request import urlopen   
import pandas as pd
import numpy as np
import requests
import os
import glob
from os import walk
from bs4 import BeautifulSoup

# %%
links = []
path = 'https://s3.amazonaws.com/tripdata/'
year_start = 2017 #2013
year_end = 2019 #2015
# loop at year
for y in range(year_start, year_end, 1):
    i = 1
    j = 13
    
    if y == 2013:
        i = 6
        
    if y == 2019:
        j = 10
      
    csv_name = ''
    if y > 2016:
        csv_name = '.csv'
    
# loop at month    
    for m in range(i, j, 1):
        s = '0'
        if m > 9:
          s = ''

        links.append(f'{path}{y}{s}{m}-citibike-tripdata{csv_name}.zip')  
        
        if (y == 2015 and m >= 9) or y > 2015:
            links.append(f'{path}JC-{y}{s}{m}-citibike-tripdata{csv_name}.zip')

    if y == 2013:
        links.append(path + '201307-201402-citibike-tripdata.zip')  
    
    if y == 2016:
        links.append(path + '201611-citibike-tripdata 23-17-16-417.zip')
        
    if y == 2017:    
        links.append(path + '201702-citibike-tripdata.csv 23-17-18-428.zip')
        links.append(path + '201704-citibike-tripdata.csv 23-17-24-762.zip')  
        
    if y == 2018:
        links.append(path + '201810-citibike-tripdata.csv 23-18-13-331.zip')

# %%
# links.append(path + '201307-201402-citibike-tripdata.zip')
# links.append(path + '201611-citibike-tripdata 23-17-16-417.zip')
# links.append(path + '201702-citibike-tripdata.csv 23-17-18-428.zip')
# links.append(path + '201704-citibike-tripdata.csv 23-17-24-762.zip')
# links.append(path + '201810-citibike-tripdata.csv 23-18-13-331.zip')

# %%
print(links)
# Out:
# ['https://s3.amazonaws.com/tripdata/201701-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/JC-201701-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/201702-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/JC-201702-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/201703-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/JC-201703-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/201704-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/JC-201704-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/201705-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/JC-201705-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/201706-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/JC-201706-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/201707-citibike-tripdata.csv.zip', 'https://s3.amazonaws.com/tripdata/JC-201707-citibike-tripdata.csv.zi
# ...

# %%
rides = []
for link in links:
    try:
        df = pd.read_csv(link, low_memory=False)
        rides.append(df)            
    except: continue

# %%
print(len(rides))
# Out:
# 47

# %%
rides[0].head(5)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
rides[46].tail(5)
# Out:
#        tripduration                 starttime                  stoptime  \
# 20200          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 20201           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 20202          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 20203          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 20204           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#        start station id start station name  start station latitude  \
# 20200              3694     Jackson Square                40.71113
# 20201              3694     Jackson Square                40.71113
# 20202              3694     Jackson Square                40.71113
# 20203              3694     Jackson Square                40.71113
# 20204              3694     Jackson Square                40.71113
#
#        start station longitude  end station id         end station name  \
# ...

# %%
# for i in range(0,23,1):
#     print(rides[i].columns)

# %%
for i,r in enumerate(rides):
    print(f'df{i}:')
    print(rides[i].columns)
# Out:
# df0:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')
# df1:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')
# df2:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
# ...

# %%
for i in range(0,6,1):
    rides[i].columns = ['tripduration', 'starttime', 'stoptime', 'start station id',
       'start station name', 'start station latitude',
       'start station longitude', 'end station id', 'end station name',
       'end station latitude', 'end station longitude', 'bikeid', 'usertype',
       'birth year', 'gender']
    print(f'df{i}:')
    print(rides[i].columns)
# Out:
# df0:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')
# df1:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')
# df2:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
# ...

# %%
rides_df = pd.concat(rides)

# %%
rides_df.count()
# Out:
# tripduration               34526344
# starttime                  34526344
# stoptime                   34526344
# start station id           34523847
# start station name         34523847
# start station latitude     34526344
# start station longitude    34526344
# end station id             34523847
# end station name           34523847
# end station latitude       34526344
# end station longitude      34526344
# bikeid                     34526344
# usertype                   34510318
# birth year                 32879063
# gender                     34526344
# dtype: int64

# %%
rides_df.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  3.452634e+07      3.452385e+07            3.452634e+07
# mean   9.863028e+02      1.508695e+03            4.073675e+01
# std    1.751677e+04      1.407503e+03            5.507632e-02
# min    6.100000e+01      7.200000e+01            0.000000e+00
# 25%    3.600000e+02      3.770000e+02            4.071775e+01
# 50%    6.070000e+02      4.990000e+02            4.073705e+01
# 75%    1.060000e+03      3.177000e+03            4.075641e+01
# max    1.951005e+07      3.721000e+03            4.550636e+01
#
#        start station longitude  end station id  end station latitude  \
# count             3.452634e+07    3.452385e+07          3.452634e+07
# mean             -7.398463e+01    1.500514e+03          4.073570e+01
# std               8.494753e-02    1.406084e+03          1.816979e-01
# min              -7.409694e+01    7.200000e+01          0.000000e+00
# ...

# %%
rides_df.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 20200          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 20201           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 20202          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 20203          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 20204           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#        start station id start station name  start station latitude  \
# 20200            3694.0     Jackson Square                40.71113
# 20201            3694.0     Jackson Square                40.71113
# 20202            3694.0     Jackson Square                40.71113
# 20203            3694.0     Jackson Square                40.71113
# 20204            3694.0     Jackson Square                40.71113
#
#        start station longitude  end station id         end station name  \
# ...

# %%
rides_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           680  2017-01-01 00:00:21  2017-01-01 00:11:41            3226.0
# 1          1282  2017-01-01 00:00:45  2017-01-01 00:22:08            3263.0
# 2           648  2017-01-01 00:00:57  2017-01-01 00:11:46            3143.0
# 3           631  2017-01-01 00:01:10  2017-01-01 00:11:42            3143.0
# 4           621  2017-01-01 00:01:25  2017-01-01 00:11:47            3143.0
#
#             start station name  start station latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    start station longitude  end station id             end station name  \
# 0               -73.971370          3165.0  Central Park West & W 72 St
# ...

# %%
def missing_data(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data
missing_data(rides_df)
# Out:
#                            Total   Percent
# birth year               1647281  4.771084
# usertype                   16026  0.046417
# end station name            2497  0.007232
# end station id              2497  0.007232
# start station name          2497  0.007232
# start station id            2497  0.007232
# gender                         0  0.000000
# bikeid                         0  0.000000
# end station longitude          0  0.000000
# end station latitude           0  0.000000
# start station longitude        0  0.000000
# start station latitude         0  0.000000
# stoptime                       0  0.000000
# starttime                      0  0.000000
# tripduration                   0  0.000000

# %%
#Ensure data is formatted correctly to avoid errors in the visuals
rides_df['starttime'] = to_datetime(rides_df['starttime'])
rides_df['stoptime'] = to_datetime(rides_df['stoptime'])
rides_df['Start Station Name'] = rides_df['Start Station Name'].astype('category')
rides_df['End Station Name'] = rides_df['End Station Name'].astype('category')
rides_df['User Type'] = rides_df['User Type'].astype('category')
rides_df['Gender'] = rides_df['Gender'].astype('category')
round(rides_df.describe(),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-4605e718511e> in <module>
#       1 #Ensure data is formatted correctly to avoid errors in the visuals
# ----> 2 rides_df['starttime'] = to_datetime(rides_df['starttime'])
#       3 rides_df['Stop Time'] = to_datetime(rides_df['Stop Time'])
#       4 rides_df['Start Station Name'] = rides_df['Start Station Name'].astype('category')
#       5 rides_df['End Station Name'] = rides_df['End Station Name'].astype('category')
#
# NameError: name 'to_datetime' is not defined

# %%
rides_df.dropna(inplace=True)

# %%
rides_df.describe()

# %%
rides_df.to_csv('Resources/Citibike_rides_2017-2018.csv', encoding='utf-8', index=False)

# %%
# citibike_rides_df = pd.concat([pd.read_csv(link) for link in Links], ignore_index = True)
# citibike_rides_df
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1                  723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2                  496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3                  306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4                  306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
# 5                 1602  2018-01-01 21:31:54.1920  2018-01-01 21:58:36.3530
# 6                  722  2018-01-02 07:54:53.6460  2018-01-02 08:06:55.8720
# 7                  434  2018-01-02 08:06:14.3310  2018-01-02 08:13:28.7670
# 8                  366  2018-01-02 08:10:15.2550  2018-01-02 08:16:21.8960
# 9                  324  2018-01-02 08:13:30.8960  2018-01-02 08:18:55.1200
# 10                1155  2018-01-02 09:15:29.9050  2018-01-02 09:34:45.0200
# ...

# %%
citibike_rides_df.to_csv('Resources/Citibike_2018.csv', encoding='utf-8', index=False)

# %%
# from urllib.request import Request, urlopen, urlretrieve
from bs4 import BeautifulSoup
def read_url(url):
#     url = url.replace(" ","%20")
#     req = requests.get(url)
    a = urlopen(url).read()
    print(a)
    soup = BeautifulSoup(a, 'html.parser')
    files = (soup.find_all('Key'))
    print(files)
    for f in files:
        file_name = f.extract().get_text()
        print(file_name)
#         url_new = url + file_name
#         url_new = url_new.replace(" ","%20")
#         if(file_name[-1]=='/' and file_name[0]!='.'):
#             read_url(url_new)
#         print(url_new)

 read_url("https://s3.amazonaws.com/tripdata/")
# Out:
#   File "<tokenize>", line 20
#     read_url("https://s3.amazonaws.com/tripdata/")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# from io import BytesIO
# from zipfile import ZipFile
# import pandas
# import requests

# url = "https://www.nseindia.com/content/indices/mcwb_jun19.zip"
# content = requests.get(url)
# zf = ZipFile(BytesIO(content.content))

# for item in zf.namelist():
#     print("File in zip: "+  item)

# # find the first matching csv file in the zip:
# match = [s for s in zf.namelist() if ".csv" in s][0]
# # the first line of the file contains a string - that line shall de     ignored, hence skiprows
# df = pandas.read_csv(zf.open(match), low_memory=False, skiprows=[0])
