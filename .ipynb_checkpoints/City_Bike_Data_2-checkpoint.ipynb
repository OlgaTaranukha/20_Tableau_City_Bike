# %%
from zipfile import ZipFile
from urllib.request import urlopen   
import pandas as pd
import numpy as np
import requests
import os
import glob
from os import walk
from bs4 import BeautifulSoup

# %%
Links_2013 = ['https://s3.amazonaws.com/tripdata/201801-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201802-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201803-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201804-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201805-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201806-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201807-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201808-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201809-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201810-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201811-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201812-citibike-tripdata.csv.zip',\
       ]

Links_2018 = ['https://s3.amazonaws.com/tripdata/201801-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201802-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201803-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201804-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201805-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201806-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201807-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201808-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201809-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201810-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201811-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201812-citibike-tripdata.csv.zip',\
       ]

# %%
links = []
path = 'https://s3.amazonaws.com/tripdata/'
year_start = 2013
year_end = 2020
for y in range(year_start, year_end, 1):
    i = 1
    j = 13
    
    if y == 2013:
        i = 6
        
    if y == 2019:
        j = 10
      
    csv_name = ''
    if y > 2016:
        csv_name = '.csv'
    
    for m in range(i, j, 1):
        s = '0'
        if m > 9:
          s = ''
        links.append(f'{path}{y}{s}{m}-citibike-tripdata{csv_name}.zip')  

links.append(path + '201307-201402-citibike-tripdata.zip')
links.append(path + '201611-citibike-tripdata 23-17-16-417.zip')
links.append(path + '201702-citibike-tripdata.csv 23-17-18-428.zip')
links.append(path + '201704-citibike-tripdata.csv 23-17-24-762.zip')
links.append(path + '201810-citibike-tripdata.csv 23-18-13-331.zip')

print(links)
# Out:
# ['https://s3.amazonaws.com/tripdata/201306-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201307-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201308-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201309-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201310-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201311-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201312-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201401-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201402-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201403-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201404-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201405-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201406-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201407-citibike-tripdata.zip', 'https://s3.amazonaws.com/tripdata/201408-citibike-tripdata.zip', 'https:
# ...

# %%
rides = []
for link in links:
    try:
        df = pd.read_csv(link)
        rides.append(df)            
    except: continue  
        
rides_df = pd.concat(rides)
# Out:
# /Users/olgataranukha/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
rides_df.describe()

# %%
rides_df.tail()
# Out:
#         tripduration            starttime             stoptime  \
# 443961          1014  2013-12-31 23:55:56  2014-01-01 00:12:50
# 443962           682  2013-12-31 23:57:04  2014-01-01 00:08:26
# 443963          1520  2013-12-31 23:57:44  2014-01-01 00:23:04
# 443964          1166  2013-12-31 23:58:14  2014-01-01 00:17:40
# 443965           677  2013-12-31 23:58:16  2014-01-01 00:09:33
#
#         start station id                 start station name  \
# 443961               350              Clinton St & Grand St
# 443962               538                    W 49 St & 5 Ave
# 443963               281  Grand Army Plaza & Central Park S
# 443964               492                    W 33 St & 7 Ave
# 443965               463                    9 Ave & W 16 St
#
#         start station latitude  start station longitude  end station id  \
# 443961               40.715595               -73.987030             532
# 443962               40.757952               -73.977876            2006
# ...

# %%
rides_df.to_csv('Resources/Citibike_rides.csv', encoding='utf-8', index=False)

# %%
# y = '2013'
# m = '06'
# df_test = pd.read_csv(f'https://s3.amazonaws.com/tripdata/{y}{m}-citibike-tripdata.csv.zip')

# %%
df_test.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  7.189940e+05     718994.000000           718994.000000
# mean   8.268107e+02       1469.519095               40.737894
# std    3.279694e+04       1398.626487                0.044702
# min    6.100000e+01         72.000000               40.646538
# 25%    3.190000e+02        377.000000               40.719079
# 50%    5.100000e+02        497.000000               40.739355
# 75%    8.420000e+02       3170.000000               40.756687
# max    1.951005e+07       3664.000000               45.506364
#
#        start station longitude  end station id  end station latitude  \
# count            718994.000000   718994.000000         718994.000000
# mean                -73.982934     1460.948474             40.737620
# std                   0.018219     1396.759046              0.044525
# min                 -74.017134       72.000000             40.646538
# ...

# %%
df_test.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
# df_list=[]
# for Link in Links:
# # open and save the zip file onto computer
#     url = urlopen(Link)
#     output = open('zipFile.zip', 'wb')           
#     output.write(url.read())
#     output.close()

# # read the zip file as a pandas dataframe
#     df = pd.read_csv('zipFile.zip')      
#     df_list.append(df)

# df = pd.concat(df_list)
# df

# df.to_csv('Resources/Citibike_2018.csv', encoding='utf-8', index=False)

# %%
citibike_rides_df = pd.concat([pd.read_csv(link) for link in Links], ignore_index = True)
citibike_rides_df
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1                  723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2                  496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3                  306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4                  306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
# 5                 1602  2018-01-01 21:31:54.1920  2018-01-01 21:58:36.3530
# 6                  722  2018-01-02 07:54:53.6460  2018-01-02 08:06:55.8720
# 7                  434  2018-01-02 08:06:14.3310  2018-01-02 08:13:28.7670
# 8                  366  2018-01-02 08:10:15.2550  2018-01-02 08:16:21.8960
# 9                  324  2018-01-02 08:13:30.8960  2018-01-02 08:18:55.1200
# 10                1155  2018-01-02 09:15:29.9050  2018-01-02 09:34:45.0200
# ...

# %%
citibike_rides_df.to_csv('Resources/Citibike_2018.csv', encoding='utf-8', index=False)

# %%
# df = pd.read_csv('https://s3.amazonaws.com/tripdata/201801-citibike-tripdata.csv.zip')
# df.head(10)

# %%
# path = 'https://s3.amazonaws.com/tripdata/index.html'
# for f in glob.glob(path):
#     print(f)

# %%
# path of zip files
# path = 'Resources/*.*'
# for f in glob.glob(path):
#     print(f)

# citibike_rides_df = pd.concat([pd.read_csv(f) for f in glob.glob(path)], ignore_index = True)

# citibike_rides_df = pd.concat([pd.read_csv(f) for f in glob.glob(path)], ignore_index = True)

# print(glob.glob(path))
# for f in os.walk(path):
#     print(f)
# files = []
# # r=root, d=directories, f = files
# for r, d, f in os.walk(path):
#     for file in f:
#         if '.zip' in file:
#             files.append(os.path.join(r, file))

# for f in files:
#     print(f)
# import glob
# glob.glob()

# folders = [f for f in glob.glob(path + "**/", recursive=True)]

# for f in folders:
#     print(f)

# %%
# from urllib.request import Request, urlopen, urlretrieve
from bs4 import BeautifulSoup
def read_url(url):
#     url = url.replace(" ","%20")
#     req = requests.get(url)
    a = urlopen(url).read()
    print(a)
    soup = BeautifulSoup(a, 'html.parser')
    files = (soup.find_all('Key'))
    print(files)
    for f in files:
        file_name = f.extract().get_text()
        print(file_name)
#         url_new = url + file_name
#         url_new = url_new.replace(" ","%20")
#         if(file_name[-1]=='/' and file_name[0]!='.'):
#             read_url(url_new)
#         print(url_new)

 read_url("https://s3.amazonaws.com/tripdata/")
# Out:
#   File "<tokenize>", line 20
#     read_url("https://s3.amazonaws.com/tripdata/")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# path of zip files
path = 'https://s3.amazonaws.com/tripdata'
for f in glob.glob(path):
    df=pd.read_csv(f)
    df.head(10)

#citibike_rides_df = pd.concat([pd.read_csv(f) for f in glob.glob(path)], ignore_index = True)
# citibike_rides_df = pd.concat([pd.read_csv(f) for f in os.listdir(path)], ignore_index = True)
# for filename in os.listdir(path):
#     citibike_rides_df = pd.concat([pd.read_csv(f) for f in os.listdir(path)], ignore_index = True)
#     df = pd.read_csv('filename.zip', compression='zip', header=0, sep=',', quotechar='"')
#     url = urlopen(Link)
#     output = open('zipFile.zip', 'wb')           
#     output.write(url.read())
#     output.close()

# # read the zip file as a pandas dataframe
#     df = pd.read_csv('zipFile.zip')      
#     df_list.append(df)

# %%
from io import BytesIO
from zipfile import ZipFile
import pandas
import requests

url = "https://www.nseindia.com/content/indices/mcwb_jun19.zip"
content = requests.get(url)
zf = ZipFile(BytesIO(content.content))

for item in zf.namelist():
    print("File in zip: "+  item)

# find the first matching csv file in the zip:
match = [s for s in zf.namelist() if ".csv" in s][0]
# the first line of the file contains a string - that line shall de     ignored, hence skiprows
df = pandas.read_csv(zf.open(match), low_memory=False, skiprows=[0])

# %%
# path of zip files
zipFileURL = 'https://s3.amazonaws.com/tripdata'

# retrieve list of URLs from the webservers
url = urlopen(zipFileURL)
usock = urllib.urlopen(zipFileURL)
parser = urllister.URLLister()
parser.feed(usock.read())
usock.close()
parser.close()

# only parse urls
for url in parser.urls: 
    citibike_rides_df = pd.concat([pd.read_csv(url)], ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c601ebb11616> in <module>
#       4 # retrieve list of URLs from the webservers
#       5 url = urlopen(zipFileURL)
# ----> 6 usock = urllib.urlopen(zipFileURL)
#       7 parser = urllister.URLLister()
#       8 parser.feed(usock.read())
#
# NameError: name 'urllib' is not defined

# %%
from urllib.request import Request, urlopen, urlretrieve
from bs4 import BeautifulSoup
def read_url(url):
    url = url.replace(" ","%20")
    req = Request(url)
    a = urlopen(req).read()
    soup = BeautifulSoup(a, 'html.parser')
    x = (soup.find_all('a'))
    for i in x:
        file_name = i.extract().get_text()
        print(file_name)
#         url_new = url + file_name
#         url_new = url_new.replace(" ","%20")
#         if(file_name[-1]=='/' and file_name[0]!='.'):
#             read_url(url_new)
#         print(url_new)

read_url("www.example.com")

# %%
# citibike_rides = pd.concat([pd.read_csv(f) for f in os.walk('raw_data/CitiBikeDailyRidershipandMembershipData/*.csv')], ignore_index = True)
# citibike_trips = pd.concat([pd.read_csv(f) for f in os.walk('raw_data/CitiBikeTripHistories/*.csv')], ignore_index = True)

# %%
# citibike_rides = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeDailyRidershipandMembershipData/*.csv')], ignore_index = True)
# citibike_trips = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeTripHistories/*.csv')], ignore_index = True)
